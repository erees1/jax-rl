# %%
import pandas as pd
import matplotlib.pyplot as plt
from collections import defaultdict
import os
import seaborn as sns
import numpy as np
import re

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from utils import parse_experiments

# %%
def plot_rewards(exp, stage):
    df, trs = parse_experiments(exp, stage)
    fig, axs = plt.subplots(ncols=2, figsize=(15,5))
    sns.lineplot(x='Episode', y='Reward', data=df, ax=axs[0]);
    df.pivot(index='Episode', columns='seed', values='Reward').plot(ax=axs[1]);

# %% [markdown]
# ## CartPole Results

# %%
exp = 'out/CartPole-v1/EPS100-LR0.002-DF0.98'
plot_rewards(exp, 'Training')

# %%
plot_rewards(exp, 'Testing')

# %% [markdown]
# ^Reinforcement learning is very unstable!
